# %% [markdown]
# # 🧠 OmniFile AI Processor — Colab Debug Notebook
# دفتر جاهز لتجربة المشروع على Google Colab، مع تثبيت الاعتماديات وتشغيل واجهة Gradio ومراجعة المخرجات.

# %%
# !nvidia-smi || true
import os, platform
print('Python:', platform.python_version())
print('Working dir:', os.getcwd())

# %%
USE_DRIVE = False  # غيّرها إلى True لو عايز تخزين دائم على Drive
if USE_DRIVE:
    from google.colab import drive
    drive.mount('/content/drive')
    PROJECT_ROOT = '/content/drive/MyDrive/OmniFile_Processor'
else:
    PROJECT_ROOT = '/content/OmniFile_Processor'
print('PROJECT_ROOT =', PROJECT_ROOT)

# %%
# !rm -rf /content/OmniFile_Processor
# !git clone https://github.com/DrAbdulmalek/OmniFile_Processor.git /content/OmniFile_Processor
# %cd /content/OmniFile_Processor

# %%
# !apt-get update -qq
# !apt-get install -y -qq poppler-utils tesseract-ocr tesseract-ocr-ara tesseract-ocr-eng libgl1 > /dev/null
# !pip install -q -r requirements-colab.txt

# %%
import os
HF_TOKEN = ''  # اختياري للنماذج المقيدة
if HF_TOKEN:
    os.environ['HF_TOKEN'] = HF_TOKEN
print('HF token set:', bool(os.environ.get('HF_TOKEN')))

# %%
import json
from pathlib import Path
required = [
    'hf_app.py',
    'requirements-colab.txt',
    'mobile_review/server.py',
    'tools/build_training_data.py',
]
for item in required:
    print(item, '=>', Path(item).exists())

# %%
from hf_app import build_app
demo = build_app()
demo.launch(share=True, debug=True)

# %%
# مثال: تحويل ملف تصحيحات إلى JSONL
# !python tools/build_training_data.py --corrections mobile_review/ocr_corrected.json --output dataset/review_dataset
