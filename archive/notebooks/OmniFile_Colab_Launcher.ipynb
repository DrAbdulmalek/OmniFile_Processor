# %% [markdown]
# # 🚀 OmniFile AI Processor — Google Colab Launcher
#
# **المطور:** Dr. Abdulmalek Tamer Al-husseini | Homs, Syria
# **GitHub:** [OmniFile_Processor](https://github.com/DrAbdulmalek/OmniFile_Processor)
#
# ---
#
# ### التعليمات:
# 1. شغّل الخلية الأولى (التثبيت)
# 2. انتظر حتى ينتهي التثبيت (~2-3 دقائق)
# 3. شغّل الخلية الثانية (إطلاق التطبيق)
# 4. اضغط على رابط Gradio Public URL
#
# > **ملاحظة:** إذا ظهرت أخطاء Gradio، شغّل خلية "إصلاح التوافق" ثم أعد إطلاق التطبيق.
#
# والله من وراء القصد

# %%
# %%bash# ========================================# الخلية 1: التثبيت والتهيئة# ========================================cd /content/rm -rf OmniFile_Processorgit clone https://github.com/DrAbdulmalek/OmniFile_Processor.gitcd OmniFile_Processorapt-get update -qq > /dev/null 2>&1apt-get install -y -qq poppler-utils tesseract-ocr tesseract-ocr-ara tesseract-ocr-eng libgl1 > /dev/null 2>&1pip install -r requirements-colab.txt > /dev/null 2>&1echo "✅ التثبيت اكتمل بنجاح!"echo "📦 الملفات:"ls -la hf_app.py config.py database.py

# %%
# ========================================# الخلية 2: إطلاق التطبيق# ========================================%cd /content/OmniFile_Processorimport osos.environ["GRADIO_ANALYTICS_ENABLED"] = "False"!python hf_app.py

# %%
# ========================================# الخلية 3: إصلاح توافق Gradio (إذا لزم الأمر)# ========================================# شغّل هذه الخلية فقط إذا ظهرت أخطاء عند الإطلاق# ثم أعد تشغيل الخلية 2%cd /content/OmniFile_Processor# Import sys to make sure the patcher can find the moduleimport syssys.path.insert(0, '/content/OmniFile_Processor')# Run the compatibility patcherfrom scripts.modify_hf_app import patch_filepatch_file("hf_app.py")print("\n✅ تم إصلاح التوافق. أعد تشغيل الخلية 2.")

# %%
# ========================================# الخلية 4: إصلاح سريع (بديل)# ========================================# شغّل هذه الخلية فقط إذا فشلت الخلية 3%cd /content/OmniFile_Processor# Fix multiple=True → file_count="multiple"!sed -i "s/multiple=True/file_count='multiple'/g" hf_app.py# Fix share=False → share=True for Colab!sed -i "s/share=False/share=True/g" hf_app.py# Remove height from Dataframe (if any)!sed -i '/gr\.Dataframe/,/)/{s/,\s*height\s*=\s*[0-9]\+//g}' hf_app.pyecho "✅ تم الإصلاح السريع. أعد تشغيل الخلية 2."
